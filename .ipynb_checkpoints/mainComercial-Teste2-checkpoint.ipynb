# %% [markdown]
# # Previsão de demanda energética
#
# Previsão de 3 horas na frente utilizando apenas uma rede.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob, os
import seaborn as sb
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
# Out:
# C:\Users\Pedro\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ## Carregar dataset residencial

# %%
casas = {}
for i, filePath in enumerate(sorted(glob.glob('Corporativo/*.csv'))):
    casas[i] = pd.read_csv(filePath).filter(['date', 'activeEnergy', 'cepa', 'cepb', 'cepc'])
    #casas[i] = casas[i].dropna(axis = 'columns', how = 'all')
    casas[i]['date'] = pd.to_datetime(casas[i]['date'], yearfirst=True, dayfirst= True, errors = 'coerce')
    casas[i]['weekDay'] = casas[i]['date'].dt.weekday
    casas[i]['hours'] = casas[i]['date'].dt.hour
    casas[i]['EnergyNextHour'] = casas[i]['activeEnergy'].shift(-1)
    casas[i]['EnergyNext2Hours'] = casas[i]['activeEnergy'].shift(-2)
    casas[i].drop(casas[i].index[-3:], inplace = True)
    #casas[i].dropna(axis = 0, how = 'any', inplace = True)
    
    #casas[i] = casas[i][casas[i]['activeEnergy'] < 4*casas[i]['activeEnergy'].std()]

# %%
a = 7

# %%
print(pd.isnull(casas[a]).any())
#df.loc[df['column_name'] == some_value]

casas[a].head()
# Out:
# date                False
# activeEnergy        False
# cepa                False
# cepb                False
# cepc                False
# weekDay             False
# hours               False
# EnergyNextHour      False
# EnergyNext2Hours    False
# dtype: bool
#                  date  activeEnergy  cepa  cepb  cepc  weekDay  hours  \
# 0 2017-03-01 00:00:00          9736  2696  5273  1767        2      0
# 1 2017-03-01 01:00:00         11733  3608  6011  2114        2      1
# 2 2017-03-01 02:00:00          9170  2498  5094  1578        2      2
# 3 2017-03-01 03:00:00         11795  3525  6087  2183        2      3
# 4 2017-03-01 04:00:00          9227  2532  5151  1544        2      4
#
#    EnergyNextHour  EnergyNext2Hours
# 0         11733.0            9170.0
# 1          9170.0           11795.0
# 2         11795.0            9227.0
# 3          9227.0            8965.0
# 4          8965.0            9402.0

# %%
casas[a].plot(x = 'date', y = ['activeEnergy'])#, xlim = ['2017-03-01 00:00:00', ['2017-03-02 00:00:00']])
plt.show()
casas[a].plot(x = 'date', y = ['activeEnergy'], xlim = ['2017-06-07 00:00:00', ['2017-06-10 00:00:00']])
plt.show()

# %% [markdown]
# ## Truncar os dados

# %%
train_set = casas[a][casas[a]['date'] < '2017-08-15 00:00:00']
test_set = casas[a][casas[a]['date'] > '2017-08-15 00:00:00']#.reset_index()

# %% [markdown]
# ## Retirar tendência

# %%
from sklearn.linear_model import LinearRegression
linearReg = LinearRegression()
#print(train_set.index.shape, train_set['activeEnergy'].shape)
linearReg.fit(train_set.index[:, np.newaxis], train_set['activeEnergy'])
train_set_without_tendency = train_set['activeEnergy'] - linearReg.predict(train_set.index[:, np.newaxis])
plt.plot(train_set['activeEnergy'])
plt.plot(train_set_without_tendency)
plt.show()

# %%
F = train_set.set_index('date')
#print(F.index.freq)
s = sm.tsa.seasonal_decompose(F.activeEnergy, freq = 24)

# %%
fig, axes = plt.subplots(4,1, figsize = (12, 6))
axes[0].plot(train_set.set_index('date')['activeEnergy'])
axes[0].set_title('Série original')
axes[1].plot(s.trend)
axes[1].set_title('Série de tendência')
axes[2].plot(s.seasonal)
axes[2].set_title('Série de sazonalidade')
axes[3].plot(s.resid)
axes[3].set_title('Série residual')
plt.tight_layout()
plt.show()

# %%
s.seasonal.plot(xlim = ['2017-06-02', '2017-06-03'])
plt.title('Sazonalidade aditiva diária')
plt.show()

# %%
train_set_without_tendency = train_set.set_index('date')['activeEnergy'] - s.trend
train_set.set_index('date').plot(y = ['activeEnergy'])
train_set_without_tendency.plot()
plt.title('Série sem tendência')
plt.legend(['Original', 'Sem tendência'])
plt.show()

# %%
train_set_without_season = train_set_without_tendency - s.seasonal
train_set.set_index('date').plot(y = ['activeEnergy'])
train_set_without_season.plot()
plt.legend(['Original', 'Sem sazonalidade e tendência'])
plt.title('Série sem sazonalidade e tendência')
plt.show()

# %%
plt.psd(s.resid.dropna(), NFFT = 512, Fs = 1/60)
plt.title('Análise espectral da série residual')
plt.show()
plt.psd(F.activeEnergy.dropna(), NFFT = 512, Fs = 1/60)
plt.title('Análise espectral da série original')
plt.show()

# %%
train_set.set_index('date', inplace = True)
train_set['ResidualSeries'] = s.resid
train_set['SeasonalSeries'] = s.seasonal
train_set['TrendSeries'] = s.trend
train_set.dropna(axis = 0, how = 'any', inplace = True)
train_set.head()
# Out:
# C:\Users\Pedro\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Pedro\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Pedro\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\Pedro\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                      activeEnergy    cepa   cepb   cepc  weekDay  hours  \
# date
# 2017-03-01 12:00:00        264522  103033  81091  80398        2     12
# 2017-03-01 13:00:00        269691  104390  83328  81973        2     13
# 2017-03-01 14:00:00        268806  104084  82742  81980        2     14
# 2017-03-01 15:00:00        269172  104314  83109  81749        2     15
# 2017-03-01 16:00:00        268889  104574  82828  81487        2     16
#
#                      EnergyNextHour  EnergyNext2Hours  ResidualSeries  \
# date
# 2017-03-01 12:00:00        269691.0          268806.0   148380.731135
# 2017-03-01 13:00:00        268806.0          269172.0   141284.887762
# 2017-03-01 14:00:00        269172.0          268889.0   117478.757993
# 2017-03-01 15:00:00        268889.0          266366.0   102418.264142
# 2017-03-01 16:00:00        266366.0          270185.0    95484.629353
#
#                      SeasonalSeries    TrendSeries
# date
# 2017-03-01 12:00:00   -42582.543635  158723.812500
# 2017-03-01 13:00:00   -30251.012762  158657.125000
# 2017-03-01 14:00:00    -7269.382993  158596.625000
# 2017-03-01 15:00:00     8161.506691  158592.229167
# 2017-03-01 16:00:00    14706.578980  158697.791667

# %%
test_set.set_index('date', inplace = True)
test_set = test_set[:'2017-08-26']
print(test_set.index.freq)
test_set.tail()
# Out:
# None
#                      activeEnergy   cepa   cepb   cepc  weekDay  hours  \
# date
# 2017-08-26 19:00:00        213210  82948  66259  64003        5     19
# 2017-08-26 20:00:00        197262  77490  61216  58556        5     20
# 2017-08-26 21:00:00        176474  68821  56236  51417        5     21
# 2017-08-26 22:00:00         89095  34215  32323  22557        5     22
# 2017-08-26 23:00:00          7201   2387   3906    908        5     23
#
#                      EnergyNextHour  EnergyNext2Hours
# date
# 2017-08-26 19:00:00        197262.0          176474.0
# 2017-08-26 20:00:00        176474.0           89095.0
# 2017-08-26 21:00:00         89095.0            7201.0
# 2017-08-26 22:00:00          7201.0            6786.0
# 2017-08-26 23:00:00          6786.0            6917.0

# %%
#test_set.set_index('date', inplace = True)
F = test_set.activeEnergy
sTest = sm.tsa.seasonal_decompose(F, freq = 24)
test_set['ResidualSeries'] = sTest.resid
test_set['SeasonalSeries'] = sTest.seasonal
test_set['TrendSeries'] = sTest.trend
test_set.dropna(axis = 0, how = 'any', inplace = True)
test_set.head()
# Out:
#                      activeEnergy   cepa   cepb   cepc  weekDay  hours  \
# date
# 2017-08-15 13:00:00        126788  51361  42453  32974        1     13
# 2017-08-15 14:00:00        123750  50479  41509  31762        1     14
# 2017-08-15 15:00:00        127227  51992  42491  32744        1     15
# 2017-08-15 16:00:00        135893  54055  46970  34868        1     16
# 2017-08-15 17:00:00        123202  47691  44351  31160        1     17
#
#                      EnergyNextHour  EnergyNext2Hours  ResidualSeries  \
# date
# 2017-08-15 13:00:00        123750.0          127227.0    -8045.765057
# 2017-08-15 14:00:00        127227.0          135893.0   -13774.848390
# 2017-08-15 15:00:00        135893.0          123202.0    -9623.969602
# 2017-08-15 16:00:00        123202.0          118356.0     -891.071875
# 2017-08-15 17:00:00        118356.0          120556.0    -9493.835133
#
#                      SeasonalSeries   TrendSeries
# date
# 2017-08-15 13:00:00    65043.660890  69790.104167
# 2017-08-15 14:00:00    67724.806723  69800.041667
# 2017-08-15 15:00:00    67029.344602  69821.625000
# 2017-08-15 16:00:00    66942.176042  69841.895833
# 2017-08-15 17:00:00    62830.897633  69864.937500

# %%
test_set.TrendSeries.plot()
test_set.SeasonalSeries.plot()
plt.legend(['Trend Series', 'Seasonal Series'])
plt.show()

# %% [markdown]
# ## Pré processamento dos dados

# %%
matrix =  casas[a].as_matrix(columns = ['activeEnergy', 'cepa', 'cepb', 'cepc', 'weekDay', 
                                        'hours', 'EnergyNextHour', 'EnergyNext2Hours']).T
print(matrix.shape)
correlationCoef = np.corrcoef(matrix[:,3:])
# Out:
# (8, 4550)

# %%
sb.heatmap(np.abs(correlationCoef),
           annot=True, cmap = 'YlOrRd', vmin = 0, vmax =  1,
          xticklabels = ['activeEnergy', 'cepa', 'cepb', 'cepc', 'weekDay', 'hours', 'EnergyNextHour', 'EnergyNext2Hours'],
          yticklabels = ['activeEnergy', 'cepa', 'cepb', 'cepc', 'weekDay', 'hours', 'EnergyNextHour', 'EnergyNext2Hours'])
plt.title('Abs Correlation matrix')
plt.show()

# %% [markdown]
# ## Regressão com Multilayer Perceptron

# %%
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using Theano backend.

# %% [markdown]
# Além do look_back, o create_dataset no Teste2 adiciona a hora e a data dos dados

# %%
def create_dataset(dataset, look_back=1, look_forward = 1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-look_forward-1):
        a = dataset[i:(i+look_back)]
        dataX.append(a)
        b = dataset[i + look_back:i + look_back + look_forward]
        dataY.append(b)

    return np.array(dataX), np.array(dataY)

# %%
train_set.shape
look_forward = 3
look_back = 6
#create_dataset(train_series, look_back = 6)

# %%
#len(train_set['ResidualSeries'].values)
train_values = train_set['ResidualSeries'].values
train_mean = train_set['ResidualSeries'].mean()
train_std = train_set['ResidualSeries'].std()
train_values -= train_mean
train_values /= train_std


test_values = test_set['ResidualSeries'].values
test_mean = test_set['ResidualSeries'].mean()
test_std = test_set['ResidualSeries'].std()
test_values -= test_mean
test_values /= test_std

x, y = create_dataset(train_values, look_back = look_back, look_forward = look_forward)
testx, testy = create_dataset(test_values, look_back = look_back, look_forward = look_forward)
print(y[-10:], '\n',train_values[-10:])
print(y.shape, x.shape)
# Out:
# [[-1.46711233 -1.02377817 -0.84689613]
#  [-1.02377817 -0.84689613 -0.77493549]
#  [-0.84689613 -0.77493549 -0.73264826]
#  [-0.77493549 -0.73264826 -0.73372001]
#  [-0.73264826 -0.73372001 -0.71534365]
#  [-0.73372001 -0.71534365 -0.46316277]
#  [-0.71534365 -0.46316277 -0.39594881]
#  [-0.46316277 -0.39594881 -0.4425703 ]
#  [-0.39594881 -0.4425703  -0.52920358]
#  [-0.4425703  -0.52920358  1.01350451]]
#  [-0.73264826 -0.73372001 -0.71534365 -0.46316277 -0.39594881 -0.4425703
#  -0.52920358  1.01350451  1.19249438  0.74975979]
# (3955, 3) (3955, 6)

# %%
model = Sequential()
model.add(Dense(32, input_dim = look_back, activation = 'tanh'))
model.add(Dense(look_forward))
model.compile(loss = 'mean_squared_error', optimizer = 'adam')

# %%
history = model.fit(x, y, epochs = 500, validation_split = 0.2, batch_size = 41, verbose =  2)
# Out:
# Train on 3164 samples, validate on 791 samples
# Epoch 1/500
# 0s - loss: 1.0110 - val_loss: 0.2644
# Epoch 2/500
# 0s - loss: 0.4278 - val_loss: 0.2517
# Epoch 3/500
# 0s - loss: 0.3696 - val_loss: 0.2480
# Epoch 4/500
# 0s - loss: 0.3546 - val_loss: 0.2374
# Epoch 5/500
# 0s - loss: 0.3472 - val_loss: 0.2346
# Epoch 6/500
# 0s - loss: 0.3413 - val_loss: 0.2323
# Epoch 7/500
# 0s - loss: 0.3394 - val_loss: 0.2312
# Epoch 8/500
# 0s - loss: 0.3355 - val_loss: 0.2291
# Epoch 9/500
# 0s - loss: 0.3334 - val_loss: 0.2309
# Epoch 10/500
# 0s - loss: 0.3319 - val_loss: 0.2266
# Epoch 11/500
# 0s - loss: 0.3322 - val_loss: 0.2265
# Epoch 12/500
# 0s - loss: 0.3300 - val_loss: 0.2278
# Epoch 13/500
# 0s - loss: 0.3288 - val_loss: 0.2367
# Epoch 14/500
# 0s - loss: 0.3278 - val_loss: 0.2273
# Epoch 15/500
# 0s - loss: 0.3268 - val_loss: 0.2245
# Epoch 16/500
# 0s - loss: 0.3261 - val_loss: 0.2315
# Epoch 17/500
# 0s - loss: 0.3254 - val_loss: 0.2325
# Epoch 18/500
# 0s - loss: 0.3259 - val_loss: 0.2261
# Epoch 19/500
# 0s - loss: 0.3243 - val_loss: 0.2313
# Epoch 20/500
# 0s - loss: 0.3242 - val_loss: 0.2305
# Epoch 21/500
# 0s - loss: 0.3230 - val_loss: 0.2318
# Epoch 22/500
# Epoch 478/500
# 0s - loss: 0.2730 - val_loss: 0.2451
# Epoch 479/500
# 0s - loss: 0.2711 - val_loss: 0.2395
# Epoch 480/500
# 0s - loss: 0.2716 - val_loss: 0.2528
# Epoch 481/500
# 0s - loss: 0.2717 - val_loss: 0.2515
# Epoch 482/500
# 0s - loss: 0.2714 - val_loss: 0.2446
# Epoch 483/500
# 0s - loss: 0.2711 - val_loss: 0.2446
# Epoch 484/500
# 0s - loss: 0.2711 - val_loss: 0.2445
# Epoch 485/500
# 0s - loss: 0.2711 - val_loss: 0.2510
# Epoch 486/500
# 0s - loss: 0.2706 - val_loss: 0.2460
# Epoch 487/500
# 0s - loss: 0.2718 - val_loss: 0.2500
# Epoch 488/500
# 0s - loss: 0.2708 - val_loss: 0.2468
# Epoch 489/500
# 0s - loss: 0.2702 - val_loss: 0.2454
# Epoch 490/500
# 0s - loss: 0.2712 - val_loss: 0.2498
# Epoch 491/500
# 0s - loss: 0.2715 - val_loss: 0.2543
# Epoch 492/500
# 0s - loss: 0.2711 - val_loss: 0.2542
# Epoch 493/500
# 0s - loss: 0.2708 - val_loss: 0.2501
# Epoch 494/500
# 0s - loss: 0.2708 - val_loss: 0.2528
# Epoch 495/500
# 0s - loss: 0.2714 - val_loss: 0.2473
# Epoch 496/500
# 0s - loss: 0.2699 - val_loss: 0.2487
# Epoch 497/500
# 0s - loss: 0.2700 - val_loss: 0.2493
# Epoch 498/500
# 0s - loss: 0.2709 - val_loss: 0.2512
# Epoch 499/500
# 0s - loss: 0.2710 - val_loss: 0.2443
# Epoch 500/500
# 0s - loss: 0.2719 - val_loss: 0.2552

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()

# %%
predictedTest = model.predict(testx)
ploting = predictedTest*test_std + test_mean 
print(test_set['SeasonalSeries'].values.shape)
ploting = ploting[:,1] + test_set['SeasonalSeries'].values[look_back-1:-look_forward-2] +test_set['TrendSeries'].values[look_back-1:-look_forward-2]
print(test_std, test_mean)
print(test_set['SeasonalSeries'].values.shape, test_set['TrendSeries'].values.shape)
print(predictedTest.shape, ploting.shape)
# Out:
# (262,)
# 21152.965950535596 -376.251799242418
# (262,) (262,)
# (252, 3) (252,)

# %%
from sklearn.metrics import mean_absolute_error
print('Mean absolute error for residual series: %.4f'%mean_absolute_error(predictedTest, testy))
print('Mean absolute error for complete series: %.4f'%mean_absolute_error(ploting, test_set['activeEnergy'][look_back-1:-look_forward-2].values))
# Out:
# Mean absolute error for residual series: 0.6758
# Mean absolute error for complete series: 9733.2001

# %%
plt.figure(figsize = (12,6))
plt.title('Predicted residual series')
plt.plot(test_set['ResidualSeries'][look_back-1:-look_forward-2].values, 'g')
plt.plot(predictedTest)
plt.legend(['Original', 'Predicted 1H', 'Predicted 2H', 'Predicted 3H'])
plt.show()

plt.figure(figsize = (12,8))
plt.title('Predicted activeEnergy')
plt.plot(test_set['activeEnergy'][look_back-1:-look_forward-2].values, 'g')
plt.plot(ploting, 'r')
plt.legend(['Original', 'Predicted'])

plt.show()
