# %% [markdown]
# # Previsão de demanda energética
#
# Previsão de 1 horas na frente utilizando apenas uma rede utilizando hora e dia como entradas.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob, os
import seaborn as sb
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
# Out:
# C:\Users\Pedro\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ## Carregar dataset residencial

# %%
casas = {}
for i, filePath in enumerate(sorted(glob.glob('Residencia/*.csv'))):
    casas[i] = pd.read_csv(filePath).filter(['date', 'activeEnergy', 'cepa', 'cepb', 'cepc'])
    #casas[i] = casas[i].dropna(axis = 'columns', how = 'all')
    casas[i]['date'] = pd.to_datetime(casas[i]['date'], yearfirst=True, dayfirst= True, errors = 'coerce')
    casas[i]['weekDay'] = casas[i]['date'].dt.weekday
    casas[i]['hours'] = casas[i]['date'].dt.hour
    casas[i]['EnergyNextHour'] = casas[i]['activeEnergy'].shift(-1)
    casas[i]['EnergyNext2Hours'] = casas[i]['activeEnergy'].shift(-2)
    casas[i].drop(casas[i].index[-3:], inplace = True)
    #casas[i].dropna(axis = 0, how = 'any', inplace = True)
    
    #casas[i] = casas[i][casas[i]['activeEnergy'] < 4*casas[i]['activeEnergy'].std()]

# %%
a = 2

# %%
print(pd.isnull(casas[a]).any())
#df.loc[df['column_name'] == some_value]

casas[a].head()
# Out:
# date                False
# activeEnergy        False
# cepa                False
# cepb                False
# cepc                False
# weekDay             False
# hours               False
# EnergyNextHour      False
# EnergyNext2Hours    False
# dtype: bool
#                  date  activeEnergy  cepa  cepb  cepc  weekDay  hours  \
# 0 2017-03-01 00:00:00          1408   192   548   668        2      0
# 1 2017-03-01 01:00:00          1316   184   512   620        2      1
# 2 2017-03-01 02:00:00          1297   171   509   617        2      2
# 3 2017-03-01 03:00:00          1278   174   499   605        2      3
# 4 2017-03-01 04:00:00          1279   187   492   600        2      4
#
#    EnergyNextHour  EnergyNext2Hours
# 0          1316.0            1297.0
# 1          1297.0            1278.0
# 2          1278.0            1279.0
# 3          1279.0            1239.0
# 4          1239.0            1255.0

# %%
casas[a].plot(x = 'date', y = ['activeEnergy'])#, xlim = ['2017-03-01 00:00:00', ['2017-03-02 00:00:00']])
plt.show()
casas[a].plot(x = 'date', y = ['activeEnergy'], xlim = ['2017-06-07 00:00:00', ['2017-06-10 00:00:00']])
plt.show()

# %% [markdown]
# ## Truncar os dados

# %%
train_set = casas[a][casas[a]['date'] < '2017-08-15 00:00:00']
test_set = casas[a][casas[a]['date'] > '2017-08-15 00:00:00']#.reset_index()

# %% [markdown]
# ## Retirar tendência

# %%
from sklearn.linear_model import LinearRegression
linearReg = LinearRegression()
#print(train_set.index.shape, train_set['activeEnergy'].shape)
linearReg.fit(train_set.index[:, np.newaxis], train_set['activeEnergy'])
train_set_without_tendency = train_set['activeEnergy'] - linearReg.predict(train_set.index[:, np.newaxis])
plt.plot(train_set['activeEnergy'])
plt.plot(train_set_without_tendency)
plt.show()

# %%
F = train_set.set_index('date')
#print(F.index.freq)
s = sm.tsa.seasonal_decompose(F.activeEnergy)

# %%
s.seasonal.plot(xlim = ['2017-06-02', '2017-06-03'])
plt.title('Sazonalidade aditiva diária')
plt.show()

# %%
train_set_without_tendency = train_set.set_index('date')['activeEnergy'] - s.trend
train_set.set_index('date').plot(y = ['activeEnergy'])
train_set_without_tendency.plot()
plt.title('Série sem tendência')
plt.legend(['Original', 'Sem tendência'])
plt.show()

# %%
train_set_without_season = train_set_without_tendency - s.seasonal
train_set.set_index('date').plot(y = ['activeEnergy'])
train_set_without_season.plot()
plt.legend(['Original', 'Sem sazonalidade e tendência'])
plt.title('Série sem sazonalidade e tendência')
plt.show()

# %%
plt.psd(s.resid.dropna(), NFFT = 512, Fs = 1/60)
plt.title('Análise espectral da série residual')
plt.show()
plt.psd(F.activeEnergy.dropna(), NFFT = 512, Fs = 1/60)
plt.title('Análise espectral da série original')
plt.show()

# %%
train_set.set_index('date', inplace = True)
train_set['ResidualSeries'] = s.resid
train_set['SeasonalSeries'] = s.seasonal
train_set['TrendSeries'] = s.trend
train_set.dropna(axis = 0, how = 'any', inplace = True)
train_set.head()
# Out:
# C:\Users\Pedro\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Pedro\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Pedro\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\Pedro\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                      activeEnergy  cepa  cepb  cepc  weekDay  hours  \
# date
# 2017-03-01 12:00:00           513   273    33   207        2     12
# 2017-03-01 13:00:00           575   335    40   200        2     13
# 2017-03-01 14:00:00           483   307    38   138        2     14
# 2017-03-01 15:00:00           550   301     8   241        2     15
# 2017-03-01 16:00:00           446   294     5   147        2     16
#
#                      EnergyNextHour  EnergyNext2Hours  ResidualSeries  \
# date
# 2017-03-01 12:00:00           575.0             483.0     -144.006249
# 2017-03-01 13:00:00           483.0             550.0      -61.558834
# 2017-03-01 14:00:00           550.0             446.0     -139.123970
# 2017-03-01 15:00:00           446.0             418.0     -110.017670
# 2017-03-01 16:00:00           418.0             420.0     -239.082931
#
#                      SeasonalSeries  TrendSeries
# date
# 2017-03-01 12:00:00     -245.827084   902.833333
# 2017-03-01 13:00:00     -268.503666   905.062500
# 2017-03-01 14:00:00     -286.688530   908.812500
# 2017-03-01 15:00:00     -251.898997   911.916667
# 2017-03-01 16:00:00     -228.896236   913.979167

# %%
test_set.set_index('date', inplace = True)
test_set = test_set[:'2017-08-26']
print(test_set.index.freq)
test_set.tail()
# Out:
# None
#                      activeEnergy  cepa  cepb  cepc  weekDay  hours  \
# date
# 2017-08-26 06:00:00           537   159   158   220        5      6
# 2017-08-26 07:00:00           505   142   101   262        5      7
# 2017-08-26 08:00:00           591   298    40   253        5      8
# 2017-08-26 09:00:00           430   261    -1   170        5      9
# 2017-08-26 10:00:00           108    82     6    20        5     10
#
#                      EnergyNextHour  EnergyNext2Hours
# date
# 2017-08-26 06:00:00           505.0             591.0
# 2017-08-26 07:00:00           591.0             430.0
# 2017-08-26 08:00:00           430.0             108.0
# 2017-08-26 09:00:00           108.0               2.0
# 2017-08-26 10:00:00             2.0               0.0

# %%
#test_set.set_index('date', inplace = True)
F = test_set.activeEnergy
sTest = sm.tsa.seasonal_decompose(F, freq = 24)
test_set['ResidualSeries'] = sTest.resid
test_set['SeasonalSeries'] = sTest.seasonal
test_set['TrendSeries'] = sTest.trend
test_set.dropna(axis = 0, how = 'any', inplace = True)
test_set.head()
# Out:
#                      activeEnergy  cepa  cepb  cepc  weekDay  hours  \
# date
# 2017-08-15 13:00:00           228   146    24    58        1     13
# 2017-08-15 14:00:00           225   182    10    33        1     14
# 2017-08-15 15:00:00           435   348    37    50        1     15
# 2017-08-15 16:00:00           594   371    44   179        1     16
# 2017-08-15 17:00:00           259   207    10    42        1     17
#
#                      EnergyNextHour  EnergyNext2Hours  ResidualSeries  \
# date
# 2017-08-15 13:00:00           225.0             435.0       74.418868
# 2017-08-15 14:00:00           435.0             594.0       75.894247
# 2017-08-15 15:00:00           594.0             259.0      132.005990
# 2017-08-15 16:00:00           259.0             259.0      302.038187
# 2017-08-15 17:00:00           259.0             297.0      -42.637950
#
#                      SeasonalSeries  TrendSeries
# date
# 2017-08-15 13:00:00     -350.439702   504.020833
# 2017-08-15 14:00:00     -357.435914   506.541667
# 2017-08-15 15:00:00     -208.443490   511.437500
# 2017-08-15 16:00:00     -222.559020   514.520833
# 2017-08-15 17:00:00     -212.028717   513.666667

# %%
test_set.TrendSeries.plot()
test_set.SeasonalSeries.plot()
plt.legend(['Trend Series', 'Seasonal Series'])
plt.show()

# %% [markdown]
# ## Pré processamento dos dados

# %%
matrix =  casas[a].as_matrix(columns = ['activeEnergy', 'cepa', 'cepb', 'cepc', 'weekDay', 
                                        'hours', 'EnergyNextHour', 'EnergyNext2Hours']).T
print(matrix.shape)
correlationCoef = np.corrcoef(matrix[:,3:])
# Out:
# (8, 4311)

# %%
sb.heatmap(np.abs(correlationCoef),
           annot=True, cmap = 'YlOrRd', vmin = 0, vmax =  1,
          xticklabels = ['activeEnergy', 'cepa', 'cepb', 'cepc', 'weekDay', 'hours', 'EnergyNextHour', 'EnergyNext2Hours'],
          yticklabels = ['activeEnergy', 'cepa', 'cepb', 'cepc', 'weekDay', 'hours', 'EnergyNextHour', 'EnergyNext2Hours'])
plt.title('Abs Correlation matrix')
plt.show()

# %% [markdown]
# ## Regressão com Multilayer Perceptron

# %%
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using Theano backend.

# %% [markdown]
# Além do look_back, o create_dataset no Teste2 adiciona a hora e a data dos dados

# %%
def create_dataset(dataset, hour, weekday, look_back=1, look_forward = 1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-look_forward-1):
        a = dataset[i:(i+look_back)]
        a = np.hstack((a, np.sin((2*np.pi/24)*hour[i]), np.sin((2*np.pi/7)*weekday[i])))
        dataX.append(a)
        
        b = dataset[i + look_back:i + look_back + look_forward]
        dataY.append(b)

    return np.array(dataX), np.array(dataY)

# %%
train_set.shape
look_forward = 1
look_back = 1
#create_dataset(train_series, look_back = 6)

# %%
#len(train_set['ResidualSeries'].values)
train_values = train_set['ResidualSeries'].values
train_mean = train_set['ResidualSeries'].mean()
train_std = train_set['ResidualSeries'].std()
train_values -= train_mean
train_values /= train_std


test_values = test_set['ResidualSeries'].values
test_mean = test_set['ResidualSeries'].mean()
test_std = test_set['ResidualSeries'].std()
test_values -= test_mean
test_values /= test_std

x, y = create_dataset(train_values,
                      hour = train_set['hours'].values, 
                      weekday = train_set['weekDay'].values, 
                      look_back = look_back, 
                      look_forward = look_forward)
testx, testy = create_dataset(test_values, 
                              hour = test_set['hours'].values,
                              weekday = test_set['weekDay'].values,
                              look_back = look_back, 
                              look_forward = look_forward)

print(y[:10], '\n',train_values[:10])
print(y.shape, x.shape)
# Out:
# [[-0.29497605]
#  [-0.66771441]
#  [-0.52784442]
#  [-1.14806603]
#  [-1.29195024]
#  [-1.30082785]
#  [-0.78276327]
#  [-0.0438935 ]
#  [ 1.9399958 ]
#  [ 1.04458519]]
#  [-0.69117614 -0.29497605 -0.66771441 -0.52784442 -1.14806603 -1.29195024
#  -1.30082785 -0.78276327 -0.0438935   1.9399958 ]
# (3981, 1) (3981, 3)

# %%
model = Sequential()
model.add(Dense(32, input_dim = look_back + 2, activation = 'relu')) # 2 devido a hora e weekday
model.add(Dense(look_forward))
model.compile(loss = 'mean_squared_error', optimizer = 'adam')

# %%
history = model.fit(x, y, epochs = 500, validation_split = 0.2, batch_size = 41, verbose =  2)
# Out:
# Train on 3184 samples, validate on 797 samples
# Epoch 1/500
# 0s - loss: 0.9972 - val_loss: 0.5836
# Epoch 2/500
# 0s - loss: 0.6174 - val_loss: 0.4583
# Epoch 3/500
# 0s - loss: 0.5599 - val_loss: 0.4462
# Epoch 4/500
# 0s - loss: 0.5534 - val_loss: 0.4417
# Epoch 5/500
# 0s - loss: 0.5506 - val_loss: 0.4394
# Epoch 6/500
# 0s - loss: 0.5494 - val_loss: 0.4371
# Epoch 7/500
# 0s - loss: 0.5475 - val_loss: 0.4359
# Epoch 8/500
# 0s - loss: 0.5469 - val_loss: 0.4364
# Epoch 9/500
# 0s - loss: 0.5458 - val_loss: 0.4379
# Epoch 10/500
# 0s - loss: 0.5442 - val_loss: 0.4380
# Epoch 11/500
# 0s - loss: 0.5444 - val_loss: 0.4398
# Epoch 12/500
# 0s - loss: 0.5434 - val_loss: 0.4336
# Epoch 13/500
# 0s - loss: 0.5438 - val_loss: 0.4324
# Epoch 14/500
# 0s - loss: 0.5427 - val_loss: 0.4384
# Epoch 15/500
# 0s - loss: 0.5432 - val_loss: 0.4362
# Epoch 16/500
# 0s - loss: 0.5421 - val_loss: 0.4380
# Epoch 17/500
# 0s - loss: 0.5408 - val_loss: 0.4378
# Epoch 18/500
# 0s - loss: 0.5411 - val_loss: 0.4365
# Epoch 19/500
# 0s - loss: 0.5399 - val_loss: 0.4367
# Epoch 20/500
# 0s - loss: 0.5387 - val_loss: 0.4358
# Epoch 21/500
# 0s - loss: 0.5387 - val_loss: 0.4396
# Epoch 22/500
# 0s - loss: 0.5392 - val_loss: 0.4357
# Epoch 23/500
# 0s - loss: 0.5385 - val_loss: 0.4345
# Epoch 24/500
# 0s - loss: 0.5377 - val_loss: 0.4392
# Epoch 25/500
# 0s - loss: 0.5377 - val_loss: 0.4403
# Epoch 26/500
# 0s - loss: 0.5380 - val_loss: 0.4374
# Epoch 27/500
# 0s - loss: 0.5375 - val_loss: 0.4366
# Epoch 28/500
# 0s - loss: 0.5363 - val_loss: 0.4357
# Epoch 29/500
# 0s - loss: 0.5370 - val_loss: 0.4351
# Epoch 30/500
# 0s - loss: 0.5364 - val_loss: 0.4386
# Epoch 31/500
# 0s - loss: 0.5354 - val_loss: 0.4387
# Epoch 32/500
# 0s - loss: 0.5351 - val_loss: 0.4378
# Epoch 33/500
# 0s - loss: 0.5348 - val_loss: 0.4392
# Epoch 34/500
# 0s - loss: 0.5352 - val_loss: 0.4378
# Epoch 35/500
# 0s - loss: 0.5346 - val_loss: 0.4386
# Epoch 36/500
# 0s - loss: 0.5351 - val_loss: 0.4381
# Epoch 37/500
# 0s - loss: 0.5336 - val_loss: 0.4371
# Epoch 38/500
# 0s - loss: 0.5343 - val_loss: 0.4405
# Epoch 39/500
# 0s - loss: 0.5336 - val_loss: 0.4349
# Epoch 40/500
# 0s - loss: 0.5337 - val_loss: 0.4370
# Epoch 41/500
# 0s - loss: 0.5334 - val_loss: 0.4377
# Epoch 42/500
# 0s - loss: 0.5328 - val_loss: 0.4363
# Epoch 43/500
# 0s - loss: 0.5333 - val_loss: 0.4377
# Epoch 44/500
# 0s - loss: 0.5320 - val_loss: 0.4386
# Epoch 45/500
# 0s - loss: 0.5319 - val_loss: 0.4401
# Epoch 46/500
# 0s - loss: 0.5319 - val_loss: 0.4412
# Epoch 47/500
# 0s - loss: 0.5324 - val_loss: 0.4374
# Epoch 48/500
# 0s - loss: 0.5310 - val_loss: 0.4424
# Epoch 49/500
# 0s - loss: 0.5315 - val_loss: 0.4366
# Epoch 50/500
# 0s - loss: 0.5311 - val_loss: 0.4378
# Epoch 51/500
# 0s - loss: 0.5306 - val_loss: 0.4398
# Epoch 52/500
# 0s - loss: 0.5309 - val_loss: 0.4394
# Epoch 53/500
# 0s - loss: 0.5298 - val_loss: 0.4403
# Epoch 54/500
# 0s - loss: 0.5297 - val_loss: 0.4401
# Epoch 55/500
# 0s - loss: 0.5298 - val_loss: 0.4417
# Epoch 56/500
# 0s - loss: 0.5293 - val_loss: 0.4402
# Epoch 57/500
# 0s - loss: 0.5291 - val_loss: 0.4369
# Epoch 58/500
# 0s - loss: 0.5294 - val_loss: 0.4379
# Epoch 59/500
# 0s - loss: 0.5300 - val_loss: 0.4380
# Epoch 60/500
# 0s - loss: 0.5288 - val_loss: 0.4355
# Epoch 61/500
# 0s - loss: 0.5282 - val_loss: 0.4392
# Epoch 62/500
# 0s - loss: 0.5281 - val_loss: 0.4419
# Epoch 63/500
# 0s - loss: 0.5281 - val_loss: 0.4402
# Epoch 64/500
# 0s - loss: 0.5289 - val_loss: 0.4395
# Epoch 65/500
# 0s - loss: 0.5275 - val_loss: 0.4359
# Epoch 66/500
# 0s - loss: 0.5271 - val_loss: 0.4374
# Epoch 67/500
# 0s - loss: 0.5279 - val_loss: 0.4405
# Epoch 68/500
# 0s - loss: 0.5278 - val_loss: 0.4391
# Epoch 69/500
# 0s - loss: 0.5272 - val_loss: 0.4403
# Epoch 70/500
# 0s - loss: 0.5266 - val_loss: 0.4377
# Epoch 71/500
# 0s - loss: 0.5270 - val_loss: 0.4384
# Epoch 72/500
# 0s - loss: 0.5265 - val_loss: 0.4367
# Epoch 73/500
# 0s - loss: 0.5270 - val_loss: 0.4381
# Epoch 74/500
# 0s - loss: 0.5258 - val_loss: 0.4416
# Epoch 75/500
# 0s - loss: 0.5257 - val_loss: 0.4373
# Epoch 76/500
# 0s - loss: 0.5257 - val_loss: 0.4374
# Epoch 77/500
# 0s - loss: 0.5261 - val_loss: 0.4402
# Epoch 78/500
# 0s - loss: 0.5256 - val_loss: 0.4398
# Epoch 79/500
# 0s - loss: 0.5250 - val_loss: 0.4370
# Epoch 80/500
# 0s - loss: 0.5265 - val_loss: 0.4398
# Epoch 81/500
# 0s - loss: 0.5260 - val_loss: 0.4368
# Epoch 82/500
# 0s - loss: 0.5252 - val_loss: 0.4397
# Epoch 83/500
# 0s - loss: 0.5248 - val_loss: 0.4388
# Epoch 84/500
# 0s - loss: 0.5264 - val_loss: 0.4382
# Epoch 85/500
# 0s - loss: 0.5247 - val_loss: 0.4422
# Epoch 86/500
# 0s - loss: 0.5254 - val_loss: 0.4388
# Epoch 87/500
# 0s - loss: 0.5247 - val_loss: 0.4390
# Epoch 88/500
# 0s - loss: 0.5239 - val_loss: 0.4430
# Epoch 89/500
# 0s - loss: 0.5246 - val_loss: 0.4406
# Epoch 90/500
# 0s - loss: 0.5241 - val_loss: 0.4400
# Epoch 91/500
# 0s - loss: 0.5248 - val_loss: 0.4382
# Epoch 92/500
# 0s - loss: 0.5236 - val_loss: 0.4390
# Epoch 93/500
# 0s - loss: 0.5231 - val_loss: 0.4400
# Epoch 94/500
# 0s - loss: 0.5233 - val_loss: 0.4397
# Epoch 95/500
# 0s - loss: 0.5237 - val_loss: 0.4359
# Epoch 96/500
# 0s - loss: 0.5239 - val_loss: 0.4385
# Epoch 97/500
# 0s - loss: 0.5230 - val_loss: 0.4392
# Epoch 98/500
# 0s - loss: 0.5216 - val_loss: 0.4378
# Epoch 99/500
# 0s - loss: 0.5236 - val_loss: 0.4431
# Epoch 100/500
# 0s - loss: 0.5223 - val_loss: 0.4379
# Epoch 101/500
# 0s - loss: 0.5213 - val_loss: 0.4415
# Epoch 102/500
# 0s - loss: 0.5215 - val_loss: 0.4392
# Epoch 103/500
# 0s - loss: 0.5212 - val_loss: 0.4382
# Epoch 104/500
# 0s - loss: 0.5214 - val_loss: 0.4418
# Epoch 105/500
# 0s - loss: 0.5218 - val_loss: 0.4403
# Epoch 106/500
# 0s - loss: 0.5229 - val_loss: 0.4371
# Epoch 107/500
# 0s - loss: 0.5226 - val_loss: 0.4387
# Epoch 108/500
# 0s - loss: 0.5211 - val_loss: 0.4383
# Epoch 109/500
# 0s - loss: 0.5211 - val_loss: 0.4442
# Epoch 110/500
# 0s - loss: 0.5209 - val_loss: 0.4387
# Epoch 111/500
# 0s - loss: 0.5205 - val_loss: 0.4368
# Epoch 112/500
# 0s - loss: 0.5203 - val_loss: 0.4395
# Epoch 113/500
# 0s - loss: 0.5202 - val_loss: 0.4422
# Epoch 114/500
# 0s - loss: 0.5199 - val_loss: 0.4382
# Epoch 115/500
# 0s - loss: 0.5220 - val_loss: 0.4394
# Epoch 116/500
# 0s - loss: 0.5190 - val_loss: 0.4414
# Epoch 117/500
# 0s - loss: 0.5196 - val_loss: 0.4406
# Epoch 118/500
# 0s - loss: 0.5208 - val_loss: 0.4405
# Epoch 119/500
# 0s - loss: 0.5189 - val_loss: 0.4392
# Epoch 120/500
# 0s - loss: 0.5192 - val_loss: 0.4425
# Epoch 121/500
# 0s - loss: 0.5198 - val_loss: 0.4421
# Epoch 122/500
# 0s - loss: 0.5194 - val_loss: 0.4426
# Epoch 123/500
# 0s - loss: 0.5206 - val_loss: 0.4409
# Epoch 124/500
# 0s - loss: 0.5182 - val_loss: 0.4401
# Epoch 125/500
# 0s - loss: 0.5191 - val_loss: 0.4389
# Epoch 126/500
# 0s - loss: 0.5189 - val_loss: 0.4415
# Epoch 127/500
# 0s - loss: 0.5183 - val_loss: 0.4404
# Epoch 128/500
# 0s - loss: 0.5178 - val_loss: 0.4404
# Epoch 129/500
# 0s - loss: 0.5185 - val_loss: 0.4394
# Epoch 130/500
# 0s - loss: 0.5184 - val_loss: 0.4399
# Epoch 131/500
# 0s - loss: 0.5178 - val_loss: 0.4449
# Epoch 132/500
# 0s - loss: 0.5177 - val_loss: 0.4373
# Epoch 133/500
# 0s - loss: 0.5189 - val_loss: 0.4404
# Epoch 134/500
# 0s - loss: 0.5188 - val_loss: 0.4438
# Epoch 135/500
# 0s - loss: 0.5186 - val_loss: 0.4393
# Epoch 136/500
# 0s - loss: 0.5180 - val_loss: 0.4389
# Epoch 137/500
# 0s - loss: 0.5167 - val_loss: 0.4408
# Epoch 138/500
# 0s - loss: 0.5160 - val_loss: 0.4414
# Epoch 139/500
# 0s - loss: 0.5171 - val_loss: 0.4369
# Epoch 140/500
# 0s - loss: 0.5165 - val_loss: 0.4420
# Epoch 141/500
# 0s - loss: 0.5170 - val_loss: 0.4431
# Epoch 142/500
# 0s - loss: 0.5166 - val_loss: 0.4371
# Epoch 143/500
# 0s - loss: 0.5169 - val_loss: 0.4393
# Epoch 144/500
# 0s - loss: 0.5164 - val_loss: 0.4442
# Epoch 145/500
# 0s - loss: 0.5160 - val_loss: 0.4425
# Epoch 146/500
# 0s - loss: 0.5163 - val_loss: 0.4426
# Epoch 147/500
# 0s - loss: 0.5164 - val_loss: 0.4401
# Epoch 148/500
# 0s - loss: 0.5162 - val_loss: 0.4377
# Epoch 149/500
# 0s - loss: 0.5155 - val_loss: 0.4457
# Epoch 150/500
# 0s - loss: 0.5150 - val_loss: 0.4425
# Epoch 151/500
# 0s - loss: 0.5153 - val_loss: 0.4409
# Epoch 152/500
# 0s - loss: 0.5161 - val_loss: 0.4383
# Epoch 153/500
# 0s - loss: 0.5156 - val_loss: 0.4421
# Epoch 154/500
# 0s - loss: 0.5152 - val_loss: 0.4378
# Epoch 155/500
# 0s - loss: 0.5154 - val_loss: 0.4408
# Epoch 156/500
# 0s - loss: 0.5160 - val_loss: 0.4419
# Epoch 157/500
# 0s - loss: 0.5156 - val_loss: 0.4397
# Epoch 158/500
# 0s - loss: 0.5148 - val_loss: 0.4422
# Epoch 159/500
# 0s - loss: 0.5147 - val_loss: 0.4406
# Epoch 160/500
# 0s - loss: 0.5163 - val_loss: 0.4390
# Epoch 161/500
# 0s - loss: 0.5153 - val_loss: 0.4420
# Epoch 162/500
# 0s - loss: 0.5137 - val_loss: 0.4418
# Epoch 163/500
# 0s - loss: 0.5141 - val_loss: 0.4378
# Epoch 164/500
# 0s - loss: 0.5150 - val_loss: 0.4390
# Epoch 165/500
# 0s - loss: 0.5147 - val_loss: 0.4386
# Epoch 166/500
# 0s - loss: 0.5128 - val_loss: 0.4438
# Epoch 167/500
# 0s - loss: 0.5140 - val_loss: 0.4438
# Epoch 168/500
# 0s - loss: 0.5142 - val_loss: 0.4425
# Epoch 169/500
# 0s - loss: 0.5149 - val_loss: 0.4421
# Epoch 170/500
# 0s - loss: 0.5139 - val_loss: 0.4433
# Epoch 171/500
# 0s - loss: 0.5124 - val_loss: 0.4416
# Epoch 172/500
# 0s - loss: 0.5135 - val_loss: 0.4401
# Epoch 173/500
# 0s - loss: 0.5140 - val_loss: 0.4445
# Epoch 174/500
# 0s - loss: 0.5139 - val_loss: 0.4426
# Epoch 175/500
# 0s - loss: 0.5131 - val_loss: 0.4463
# Epoch 176/500
# 0s - loss: 0.5139 - val_loss: 0.4401
# Epoch 177/500
# 0s - loss: 0.5144 - val_loss: 0.4439
# Epoch 178/500
# 0s - loss: 0.5145 - val_loss: 0.4415
# Epoch 179/500
# 0s - loss: 0.5134 - val_loss: 0.4413
# Epoch 180/500
# 0s - loss: 0.5144 - val_loss: 0.4417
# Epoch 181/500
# 0s - loss: 0.5117 - val_loss: 0.4417
# Epoch 182/500
# 0s - loss: 0.5125 - val_loss: 0.4418
# Epoch 183/500
# 0s - loss: 0.5126 - val_loss: 0.4428
# Epoch 184/500
# 0s - loss: 0.5122 - val_loss: 0.4430
# Epoch 185/500
# 0s - loss: 0.5124 - val_loss: 0.4403
# Epoch 186/500
# 0s - loss: 0.5125 - val_loss: 0.4427
# Epoch 187/500
# 0s - loss: 0.5125 - val_loss: 0.4445
# Epoch 188/500
# 0s - loss: 0.5131 - val_loss: 0.4422
# Epoch 189/500
# 0s - loss: 0.5128 - val_loss: 0.4456
# Epoch 190/500
# 0s - loss: 0.5131 - val_loss: 0.4400
# Epoch 191/500
# 0s - loss: 0.5132 - val_loss: 0.4408
# Epoch 192/500
# 0s - loss: 0.5127 - val_loss: 0.4432
# Epoch 193/500
# 0s - loss: 0.5126 - val_loss: 0.4453
# Epoch 194/500
# 0s - loss: 0.5112 - val_loss: 0.4420
# Epoch 195/500
# 0s - loss: 0.5113 - val_loss: 0.4434
# Epoch 196/500
# 0s - loss: 0.5119 - val_loss: 0.4465
# Epoch 197/500
# 0s - loss: 0.5129 - val_loss: 0.4450
# Epoch 198/500
# 0s - loss: 0.5122 - val_loss: 0.4454
# Epoch 199/500
# 0s - loss: 0.5112 - val_loss: 0.4453
# Epoch 200/500
# 0s - loss: 0.5114 - val_loss: 0.4446
# Epoch 201/500
# 0s - loss: 0.5114 - val_loss: 0.4468
# Epoch 202/500
# 0s - loss: 0.5122 - val_loss: 0.4445
# Epoch 203/500
# 0s - loss: 0.5115 - val_loss: 0.4443
# Epoch 204/500
# 0s - loss: 0.5106 - val_loss: 0.4422
# Epoch 205/500
# 0s - loss: 0.5107 - val_loss: 0.4435
# Epoch 206/500
# 0s - loss: 0.5106 - val_loss: 0.4475
# Epoch 207/500
# 0s - loss: 0.5124 - val_loss: 0.4450
# Epoch 208/500
# 0s - loss: 0.5110 - val_loss: 0.4457
# Epoch 209/500
# 0s - loss: 0.5112 - val_loss: 0.4434
# Epoch 210/500
# 0s - loss: 0.5103 - val_loss: 0.4464
# Epoch 211/500
# 0s - loss: 0.5114 - val_loss: 0.4448
# Epoch 212/500
# 0s - loss: 0.5111 - val_loss: 0.4450
# Epoch 213/500
# 0s - loss: 0.5102 - val_loss: 0.4459
# Epoch 214/500
# 0s - loss: 0.5110 - val_loss: 0.4471
# Epoch 215/500
# 0s - loss: 0.5120 - val_loss: 0.4438
# Epoch 216/500
# 0s - loss: 0.5113 - val_loss: 0.4423
# Epoch 217/500
# 0s - loss: 0.5112 - val_loss: 0.4432
# Epoch 218/500
# 0s - loss: 0.5113 - val_loss: 0.4485
# Epoch 219/500
# 0s - loss: 0.5114 - val_loss: 0.4404
# Epoch 220/500
# 0s - loss: 0.5097 - val_loss: 0.4451
# Epoch 221/500
# 0s - loss: 0.5108 - val_loss: 0.4500
# Epoch 222/500
# 0s - loss: 0.5094 - val_loss: 0.4467
# Epoch 223/500
# 0s - loss: 0.5105 - val_loss: 0.4437
# Epoch 224/500
# 0s - loss: 0.5093 - val_loss: 0.4415
# Epoch 225/500
# 0s - loss: 0.5115 - val_loss: 0.4464
# Epoch 226/500
# 0s - loss: 0.5100 - val_loss: 0.4459
# Epoch 227/500
# 0s - loss: 0.5107 - val_loss: 0.4421
# Epoch 228/500
# 0s - loss: 0.5101 - val_loss: 0.4468
# Epoch 229/500
# 0s - loss: 0.5092 - val_loss: 0.4402
# Epoch 230/500
# 0s - loss: 0.5101 - val_loss: 0.4470
# Epoch 231/500
# 0s - loss: 0.5099 - val_loss: 0.4424
# Epoch 232/500
# 0s - loss: 0.5090 - val_loss: 0.4433
# Epoch 233/500
# 0s - loss: 0.5100 - val_loss: 0.4406
# Epoch 234/500
# 0s - loss: 0.5094 - val_loss: 0.4476
# Epoch 235/500
# 0s - loss: 0.5097 - val_loss: 0.4469
# Epoch 236/500
# 0s - loss: 0.5107 - val_loss: 0.4420
# Epoch 237/500
# 0s - loss: 0.5106 - val_loss: 0.4456
# Epoch 238/500
# 0s - loss: 0.5091 - val_loss: 0.4443
# Epoch 239/500
# 0s - loss: 0.5092 - val_loss: 0.4494
# Epoch 240/500
# 0s - loss: 0.5092 - val_loss: 0.4443
# Epoch 241/500
# 0s - loss: 0.5095 - val_loss: 0.4446
# Epoch 242/500
# 0s - loss: 0.5102 - val_loss: 0.4451
# Epoch 243/500
# 0s - loss: 0.5091 - val_loss: 0.4457
# Epoch 244/500
# 0s - loss: 0.5101 - val_loss: 0.4460
# Epoch 245/500
# 0s - loss: 0.5114 - val_loss: 0.4460
# Epoch 246/500
# 0s - loss: 0.5085 - val_loss: 0.4450
# Epoch 247/500
# 0s - loss: 0.5106 - val_loss: 0.4453
# Epoch 248/500
# 0s - loss: 0.5086 - val_loss: 0.4481
# Epoch 249/500
# 0s - loss: 0.5118 - val_loss: 0.4410
# Epoch 250/500
# 0s - loss: 0.5094 - val_loss: 0.4446
# Epoch 251/500
# 0s - loss: 0.5079 - val_loss: 0.4480
# Epoch 252/500
# 0s - loss: 0.5106 - val_loss: 0.4446
# Epoch 253/500
# 0s - loss: 0.5090 - val_loss: 0.4456
# Epoch 254/500
# 0s - loss: 0.5075 - val_loss: 0.4454
# Epoch 255/500
# 0s - loss: 0.5103 - val_loss: 0.4475
# Epoch 256/500
# 0s - loss: 0.5094 - val_loss: 0.4468
# Epoch 257/500
# 0s - loss: 0.5093 - val_loss: 0.4449
# Epoch 258/500
# 0s - loss: 0.5083 - val_loss: 0.4426
# Epoch 259/500
# 0s - loss: 0.5095 - val_loss: 0.4498
# Epoch 260/500
# 0s - loss: 0.5089 - val_loss: 0.4497
# Epoch 261/500
# 0s - loss: 0.5102 - val_loss: 0.4446
# Epoch 262/500
# 0s - loss: 0.5090 - val_loss: 0.4470
# Epoch 263/500
# 0s - loss: 0.5108 - val_loss: 0.4490
# Epoch 264/500
# 0s - loss: 0.5103 - val_loss: 0.4469
# Epoch 265/500
# 0s - loss: 0.5089 - val_loss: 0.4460
# Epoch 266/500
# 0s - loss: 0.5079 - val_loss: 0.4469
# Epoch 267/500
# 0s - loss: 0.5096 - val_loss: 0.4438
# Epoch 268/500
# 0s - loss: 0.5097 - val_loss: 0.4472
# Epoch 269/500
# 0s - loss: 0.5092 - val_loss: 0.4440
# Epoch 270/500
# 0s - loss: 0.5094 - val_loss: 0.4465
# Epoch 271/500
# 0s - loss: 0.5095 - val_loss: 0.4452
# Epoch 272/500
# 0s - loss: 0.5092 - val_loss: 0.4464
# Epoch 273/500
# 0s - loss: 0.5110 - val_loss: 0.4480
# Epoch 274/500
# 0s - loss: 0.5106 - val_loss: 0.4431
# Epoch 275/500
# 0s - loss: 0.5085 - val_loss: 0.4425
# Epoch 276/500
# 0s - loss: 0.5083 - val_loss: 0.4428
# Epoch 277/500
# 0s - loss: 0.5091 - val_loss: 0.4412
# Epoch 278/500
# 0s - loss: 0.5090 - val_loss: 0.4444
# Epoch 279/500
# 0s - loss: 0.5087 - val_loss: 0.4473
# Epoch 280/500
# 0s - loss: 0.5087 - val_loss: 0.4412
# Epoch 281/500
# 0s - loss: 0.5078 - val_loss: 0.4439
# Epoch 282/500
# 0s - loss: 0.5075 - val_loss: 0.4463
# Epoch 283/500
# 0s - loss: 0.5086 - val_loss: 0.4442
# Epoch 284/500
# 0s - loss: 0.5075 - val_loss: 0.4435
# Epoch 285/500
# 0s - loss: 0.5083 - val_loss: 0.4432
# Epoch 286/500
# 0s - loss: 0.5098 - val_loss: 0.4442
# Epoch 287/500
# 0s - loss: 0.5075 - val_loss: 0.4464
# Epoch 288/500
# 0s - loss: 0.5075 - val_loss: 0.4474
# Epoch 289/500
# 0s - loss: 0.5084 - val_loss: 0.4514
# Epoch 290/500
# 0s - loss: 0.5083 - val_loss: 0.4474
# Epoch 291/500
# 0s - loss: 0.5092 - val_loss: 0.4487
# Epoch 292/500
# 0s - loss: 0.5085 - val_loss: 0.4481
# Epoch 293/500
# 0s - loss: 0.5070 - val_loss: 0.4460
# Epoch 294/500
# 0s - loss: 0.5088 - val_loss: 0.4443
# Epoch 295/500
# 0s - loss: 0.5068 - val_loss: 0.4433
# Epoch 296/500
# 0s - loss: 0.5074 - val_loss: 0.4466
# Epoch 297/500
# 0s - loss: 0.5092 - val_loss: 0.4422
# Epoch 298/500
# 0s - loss: 0.5084 - val_loss: 0.4451
# Epoch 299/500
# 0s - loss: 0.5084 - val_loss: 0.4439
# Epoch 300/500
# 0s - loss: 0.5073 - val_loss: 0.4406
# Epoch 301/500
# 0s - loss: 0.5067 - val_loss: 0.4465
# Epoch 302/500
# 0s - loss: 0.5073 - val_loss: 0.4494
# Epoch 303/500
# 0s - loss: 0.5080 - val_loss: 0.4436
# Epoch 304/500
# 0s - loss: 0.5079 - val_loss: 0.4470
# Epoch 305/500
# 0s - loss: 0.5066 - val_loss: 0.4423
# Epoch 306/500
# 0s - loss: 0.5069 - val_loss: 0.4451
# Epoch 307/500
# 0s - loss: 0.5075 - val_loss: 0.4438
# Epoch 308/500
# 0s - loss: 0.5070 - val_loss: 0.4464
# Epoch 309/500
# 0s - loss: 0.5068 - val_loss: 0.4428
# Epoch 310/500
# 0s - loss: 0.5079 - val_loss: 0.4457
# Epoch 311/500
# 0s - loss: 0.5074 - val_loss: 0.4454
# Epoch 312/500
# 0s - loss: 0.5082 - val_loss: 0.4445
# Epoch 313/500
# 0s - loss: 0.5075 - val_loss: 0.4430
# Epoch 314/500
# 0s - loss: 0.5071 - val_loss: 0.4460
# Epoch 315/500
# 0s - loss: 0.5086 - val_loss: 0.4461
# Epoch 316/500
# 0s - loss: 0.5075 - val_loss: 0.4453
# Epoch 317/500
# 0s - loss: 0.5075 - val_loss: 0.4425
# Epoch 318/500
# 0s - loss: 0.5058 - val_loss: 0.4465
# Epoch 319/500
# 0s - loss: 0.5063 - val_loss: 0.4426
# Epoch 320/500
# 0s - loss: 0.5081 - val_loss: 0.4487
# Epoch 321/500
# 0s - loss: 0.5073 - val_loss: 0.4437
# Epoch 322/500
# 0s - loss: 0.5059 - val_loss: 0.4443
# Epoch 323/500
# 0s - loss: 0.5071 - val_loss: 0.4435
# Epoch 324/500
# 0s - loss: 0.5076 - val_loss: 0.4457
# Epoch 325/500
# 0s - loss: 0.5070 - val_loss: 0.4428
# Epoch 326/500
# 0s - loss: 0.5063 - val_loss: 0.4493
# Epoch 327/500
# 0s - loss: 0.5067 - val_loss: 0.4427
# Epoch 328/500
# 0s - loss: 0.5062 - val_loss: 0.4442
# Epoch 329/500
# 0s - loss: 0.5070 - val_loss: 0.4435
# Epoch 330/500
# 0s - loss: 0.5065 - val_loss: 0.4441
# Epoch 331/500
# 0s - loss: 0.5070 - val_loss: 0.4466
# Epoch 332/500
# 0s - loss: 0.5060 - val_loss: 0.4446
# Epoch 333/500
# 0s - loss: 0.5060 - val_loss: 0.4427
# Epoch 334/500
# 0s - loss: 0.5049 - val_loss: 0.4473
# Epoch 335/500
# 0s - loss: 0.5062 - val_loss: 0.4488
# Epoch 336/500
# 0s - loss: 0.5084 - val_loss: 0.4510
# Epoch 337/500
# 0s - loss: 0.5074 - val_loss: 0.4410
# Epoch 338/500
# 0s - loss: 0.5068 - val_loss: 0.4425
# Epoch 339/500
# 0s - loss: 0.5068 - val_loss: 0.4432
# Epoch 340/500
# 0s - loss: 0.5076 - val_loss: 0.4458
# Epoch 341/500
# 0s - loss: 0.5061 - val_loss: 0.4481
# Epoch 342/500
# 0s - loss: 0.5065 - val_loss: 0.4447
# Epoch 343/500
# 0s - loss: 0.5080 - val_loss: 0.4447
# Epoch 344/500
# 0s - loss: 0.5075 - val_loss: 0.4443
# Epoch 345/500
# 0s - loss: 0.5053 - val_loss: 0.4433
# Epoch 346/500
# 0s - loss: 0.5055 - val_loss: 0.4412
# Epoch 347/500
# 0s - loss: 0.5065 - val_loss: 0.4444
# Epoch 348/500
# 0s - loss: 0.5063 - val_loss: 0.4453
# Epoch 349/500
# 0s - loss: 0.5069 - val_loss: 0.4416
# Epoch 350/500
# 0s - loss: 0.5065 - val_loss: 0.4432
# Epoch 351/500
# 0s - loss: 0.5084 - val_loss: 0.4417
# Epoch 352/500
# 0s - loss: 0.5065 - val_loss: 0.4425
# Epoch 353/500
# 0s - loss: 0.5072 - val_loss: 0.4434
# Epoch 354/500
# 0s - loss: 0.5060 - val_loss: 0.4480
# Epoch 355/500
# 0s - loss: 0.5066 - val_loss: 0.4413
# Epoch 356/500
# 0s - loss: 0.5074 - val_loss: 0.4495
# Epoch 357/500
# 0s - loss: 0.5048 - val_loss: 0.4459
# Epoch 358/500
# 0s - loss: 0.5075 - val_loss: 0.4441
# Epoch 359/500
# 0s - loss: 0.5060 - val_loss: 0.4436
# Epoch 360/500
# 0s - loss: 0.5074 - val_loss: 0.4413
# Epoch 361/500
# 0s - loss: 0.5073 - val_loss: 0.4459
# Epoch 362/500
# 0s - loss: 0.5057 - val_loss: 0.4414
# Epoch 363/500
# 0s - loss: 0.5053 - val_loss: 0.4470
# Epoch 364/500
# 0s - loss: 0.5056 - val_loss: 0.4454
# Epoch 365/500
# 0s - loss: 0.5065 - val_loss: 0.4465
# Epoch 366/500
# 0s - loss: 0.5048 - val_loss: 0.4465
# Epoch 367/500
# 0s - loss: 0.5057 - val_loss: 0.4470
# Epoch 368/500
# 0s - loss: 0.5076 - val_loss: 0.4468
# Epoch 369/500
# 0s - loss: 0.5063 - val_loss: 0.4468
# Epoch 370/500
# 0s - loss: 0.5064 - val_loss: 0.4430
# Epoch 371/500
# 0s - loss: 0.5056 - val_loss: 0.4436
# Epoch 372/500
# 0s - loss: 0.5059 - val_loss: 0.4461
# Epoch 373/500
# 0s - loss: 0.5055 - val_loss: 0.4445
# Epoch 374/500
# 0s - loss: 0.5052 - val_loss: 0.4434
# Epoch 375/500
# 0s - loss: 0.5061 - val_loss: 0.4493
# Epoch 376/500
# 0s - loss: 0.5056 - val_loss: 0.4411
# Epoch 377/500
# 0s - loss: 0.5062 - val_loss: 0.4477
# Epoch 378/500
# 0s - loss: 0.5056 - val_loss: 0.4462
# Epoch 379/500
# 0s - loss: 0.5050 - val_loss: 0.4462
# Epoch 380/500
# 0s - loss: 0.5064 - val_loss: 0.4480
# Epoch 381/500
# 0s - loss: 0.5063 - val_loss: 0.4500
# Epoch 382/500
# 0s - loss: 0.5078 - val_loss: 0.4475
# Epoch 383/500
# 0s - loss: 0.5053 - val_loss: 0.4493
# Epoch 384/500
# 0s - loss: 0.5065 - val_loss: 0.4467
# Epoch 385/500
# 0s - loss: 0.5052 - val_loss: 0.4428
# Epoch 386/500
# 0s - loss: 0.5081 - val_loss: 0.4475
# Epoch 387/500
# 0s - loss: 0.5048 - val_loss: 0.4433
# Epoch 388/500
# 0s - loss: 0.5063 - val_loss: 0.4455
# Epoch 389/500
# 0s - loss: 0.5059 - val_loss: 0.4460
# Epoch 390/500
# 0s - loss: 0.5052 - val_loss: 0.4428
# Epoch 391/500
# 0s - loss: 0.5067 - val_loss: 0.4466
# Epoch 392/500
# 0s - loss: 0.5049 - val_loss: 0.4409
# Epoch 393/500
# 0s - loss: 0.5075 - val_loss: 0.4485
# Epoch 394/500
# 0s - loss: 0.5044 - val_loss: 0.4431
# Epoch 395/500
# 0s - loss: 0.5063 - val_loss: 0.4445
# Epoch 396/500
# 0s - loss: 0.5055 - val_loss: 0.4471
# Epoch 397/500
# 0s - loss: 0.5052 - val_loss: 0.4444
# Epoch 398/500
# 0s - loss: 0.5053 - val_loss: 0.4449
# Epoch 399/500
# 0s - loss: 0.5047 - val_loss: 0.4415
# Epoch 400/500
# 0s - loss: 0.5050 - val_loss: 0.4465
# Epoch 401/500
# 0s - loss: 0.5054 - val_loss: 0.4425
# Epoch 402/500
# 0s - loss: 0.5061 - val_loss: 0.4448
# Epoch 403/500
# 0s - loss: 0.5041 - val_loss: 0.4456
# Epoch 404/500
# 0s - loss: 0.5060 - val_loss: 0.4445
# Epoch 405/500
# 0s - loss: 0.5066 - val_loss: 0.4472
# Epoch 406/500
# 0s - loss: 0.5039 - val_loss: 0.4460
# Epoch 407/500
# 0s - loss: 0.5061 - val_loss: 0.4434
# Epoch 408/500
# 0s - loss: 0.5067 - val_loss: 0.4467
# Epoch 409/500
# 0s - loss: 0.5038 - val_loss: 0.4504
# Epoch 410/500
# 0s - loss: 0.5047 - val_loss: 0.4464
# Epoch 411/500
# 0s - loss: 0.5054 - val_loss: 0.4463
# Epoch 412/500
# 0s - loss: 0.5055 - val_loss: 0.4428
# Epoch 413/500
# 0s - loss: 0.5054 - val_loss: 0.4473
# Epoch 414/500
# 0s - loss: 0.5058 - val_loss: 0.4442
# Epoch 415/500
# 0s - loss: 0.5046 - val_loss: 0.4435
# Epoch 416/500
# 0s - loss: 0.5055 - val_loss: 0.4450
# Epoch 417/500
# 0s - loss: 0.5037 - val_loss: 0.4434
# Epoch 418/500
# 0s - loss: 0.5063 - val_loss: 0.4484
# Epoch 419/500
# 0s - loss: 0.5059 - val_loss: 0.4442
# Epoch 420/500
# 0s - loss: 0.5047 - val_loss: 0.4478
# Epoch 421/500
# 0s - loss: 0.5054 - val_loss: 0.4452
# Epoch 422/500
# 0s - loss: 0.5050 - val_loss: 0.4469
# Epoch 423/500
# 0s - loss: 0.5052 - val_loss: 0.4438
# Epoch 424/500
# 0s - loss: 0.5051 - val_loss: 0.4497
# Epoch 425/500
# 0s - loss: 0.5039 - val_loss: 0.4476
# Epoch 426/500
# 0s - loss: 0.5063 - val_loss: 0.4513
# Epoch 427/500
# 0s - loss: 0.5023 - val_loss: 0.4416
# Epoch 428/500
# 0s - loss: 0.5055 - val_loss: 0.4431
# Epoch 429/500
# 0s - loss: 0.5049 - val_loss: 0.4516
# Epoch 430/500
# 0s - loss: 0.5052 - val_loss: 0.4484
# Epoch 431/500
# 0s - loss: 0.5060 - val_loss: 0.4505
# Epoch 432/500
# 0s - loss: 0.5059 - val_loss: 0.4446
# Epoch 433/500
# 0s - loss: 0.5056 - val_loss: 0.4474
# Epoch 434/500
# 0s - loss: 0.5058 - val_loss: 0.4412
# Epoch 435/500
# 0s - loss: 0.5067 - val_loss: 0.4487
# Epoch 436/500
# 0s - loss: 0.5049 - val_loss: 0.4483
# Epoch 437/500
# 0s - loss: 0.5052 - val_loss: 0.4439
# Epoch 438/500
# 0s - loss: 0.5069 - val_loss: 0.4465
# Epoch 439/500
# 0s - loss: 0.5050 - val_loss: 0.4441
# Epoch 440/500
# 0s - loss: 0.5047 - val_loss: 0.4442
# Epoch 441/500
# 0s - loss: 0.5056 - val_loss: 0.4445
# Epoch 442/500
# 0s - loss: 0.5049 - val_loss: 0.4458
# Epoch 443/500
# 0s - loss: 0.5050 - val_loss: 0.4473
# Epoch 444/500
# 0s - loss: 0.5050 - val_loss: 0.4476
# Epoch 445/500
# 0s - loss: 0.5043 - val_loss: 0.4449
# Epoch 446/500
# 0s - loss: 0.5048 - val_loss: 0.4414
# Epoch 447/500
# 0s - loss: 0.5050 - val_loss: 0.4481
# Epoch 448/500
# 0s - loss: 0.5056 - val_loss: 0.4451
# Epoch 449/500
# 0s - loss: 0.5039 - val_loss: 0.4463
# Epoch 450/500
# 0s - loss: 0.5044 - val_loss: 0.4444
# Epoch 451/500
# 0s - loss: 0.5037 - val_loss: 0.4488
# Epoch 452/500
# 0s - loss: 0.5049 - val_loss: 0.4432
# Epoch 453/500
# 0s - loss: 0.5038 - val_loss: 0.4448
# Epoch 454/500
# 0s - loss: 0.5052 - val_loss: 0.4443
# Epoch 455/500
# 0s - loss: 0.5040 - val_loss: 0.4476
# Epoch 456/500
# 0s - loss: 0.5054 - val_loss: 0.4424
# Epoch 457/500
# 0s - loss: 0.5055 - val_loss: 0.4466
# Epoch 458/500
# 0s - loss: 0.5046 - val_loss: 0.4468
# Epoch 459/500
# 0s - loss: 0.5044 - val_loss: 0.4435
# Epoch 460/500
# 0s - loss: 0.5054 - val_loss: 0.4434
# Epoch 461/500
# 0s - loss: 0.5052 - val_loss: 0.4509
# Epoch 462/500
# 0s - loss: 0.5053 - val_loss: 0.4439
# Epoch 463/500
# 0s - loss: 0.5052 - val_loss: 0.4443
# Epoch 464/500
# 0s - loss: 0.5055 - val_loss: 0.4469
# Epoch 465/500
# 0s - loss: 0.5049 - val_loss: 0.4470
# Epoch 466/500
# 0s - loss: 0.5040 - val_loss: 0.4459
# Epoch 467/500
# 0s - loss: 0.5052 - val_loss: 0.4425
# Epoch 468/500
# 0s - loss: 0.5051 - val_loss: 0.4443
# Epoch 469/500
# 0s - loss: 0.5044 - val_loss: 0.4452
# Epoch 470/500
# 0s - loss: 0.5037 - val_loss: 0.4460
# Epoch 471/500
# 0s - loss: 0.5060 - val_loss: 0.4446
# Epoch 472/500
# 0s - loss: 0.5058 - val_loss: 0.4511
# Epoch 473/500
# 0s - loss: 0.5062 - val_loss: 0.4447
# Epoch 474/500
# 0s - loss: 0.5046 - val_loss: 0.4430
# Epoch 475/500
# 0s - loss: 0.5046 - val_loss: 0.4439
# Epoch 476/500
# 0s - loss: 0.5039 - val_loss: 0.4472
# Epoch 477/500
# 0s - loss: 0.5032 - val_loss: 0.4516
# Epoch 478/500
# 0s - loss: 0.5049 - val_loss: 0.4468
# Epoch 479/500
# 0s - loss: 0.5037 - val_loss: 0.4428
# Epoch 480/500
# 0s - loss: 0.5044 - val_loss: 0.4447
# Epoch 481/500
# 0s - loss: 0.5039 - val_loss: 0.4482
# Epoch 482/500
# 0s - loss: 0.5033 - val_loss: 0.4440
# Epoch 483/500
# 0s - loss: 0.5036 - val_loss: 0.4446
# Epoch 484/500
# 0s - loss: 0.5049 - val_loss: 0.4409
# Epoch 485/500
# 0s - loss: 0.5044 - val_loss: 0.4487
# Epoch 486/500
# 0s - loss: 0.5034 - val_loss: 0.4435
# Epoch 487/500
# 0s - loss: 0.5041 - val_loss: 0.4457
# Epoch 488/500
# 0s - loss: 0.5052 - val_loss: 0.4452
# Epoch 489/500
# 0s - loss: 0.5053 - val_loss: 0.4432
# Epoch 490/500
# 0s - loss: 0.5035 - val_loss: 0.4449
# Epoch 491/500
# 0s - loss: 0.5034 - val_loss: 0.4500
# Epoch 492/500
# 0s - loss: 0.5049 - val_loss: 0.4436
# Epoch 493/500
# 0s - loss: 0.5038 - val_loss: 0.4471
# Epoch 494/500
# 0s - loss: 0.5035 - val_loss: 0.4485
# Epoch 495/500
# 0s - loss: 0.5021 - val_loss: 0.4450
# Epoch 496/500
# 0s - loss: 0.5028 - val_loss: 0.4465
# Epoch 497/500
# 0s - loss: 0.5042 - val_loss: 0.4410
# Epoch 498/500
# 0s - loss: 0.5029 - val_loss: 0.4469
# Epoch 499/500
# 0s - loss: 0.5045 - val_loss: 0.4437
# Epoch 500/500
# 0s - loss: 0.5034 - val_loss: 0.4468

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Loss', 'Val_loss'])
plt.show()

# %%
predictedTest = model.predict(testx)
ploting = predictedTest*test_std + test_mean 
print(test_set['SeasonalSeries'].values.shape)
ploting = ploting + test_set['SeasonalSeries'].values[1:-2, np.newaxis] + test_set['TrendSeries'].values[1:-2, np.newaxis]
print(test_std, test_mean)
print(test_set['SeasonalSeries'].values.shape, test_set['TrendSeries'].values.shape)
print(predictedTest.shape, ploting.shape)
# Out:
# (249,)
# 178.1663610617089 3.8393229166667258
# (249,) (249,)
# (246, 1) (246, 1)

# %%
from sklearn.metrics import mean_absolute_error
print('Mean absolute error for residual series: %.4f'%mean_absolute_error(predictedTest, testy))
print('Mean absolute error for complete series: %.4f'%mean_absolute_error(ploting, test_set['activeEnergy'][1:-2].values))
# Out:
# Mean absolute error for residual series: 0.6412
# Mean absolute error for complete series: 114.2404

# %%
plt.figure(figsize = (12,6))
plt.title('Predicted residual series')
plt.plot(test_set['ResidualSeries'][1:-2].values, 'g')
plt.plot(predictedTest)
plt.legend(['Original', 'Predicted 1H', 'Predicted 2H', 'Predicted 3H'])
plt.show()

plt.figure(figsize = (12,8))
plt.title('Predicted activeEnergy')
plt.plot(test_set['activeEnergy'][1:-2].values, 'g')
plt.plot(ploting, 'r')
plt.legend(['Original', 'Predicted'])

plt.show()
