# %% [markdown]
# # Previsão de demanda energética
#
# Previsão de 1 hora na frente utilizando apenas uma rede.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob, os
import seaborn as sb
import statsmodels.api as sm
# Out:
# C:\Users\Pedro\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ## Carregar dataset residencial

# %%
casas = {}
for i, filePath in enumerate(sorted(glob.glob('Residencia/*.csv'))):
    casas[i] = pd.read_csv(filePath).filter(['date', 'activeEnergy', 'cepa', 'cepb', 'cepc'])
    #casas[i] = casas[i].dropna(axis = 'columns', how = 'all')
    casas[i]['date'] = pd.to_datetime(casas[i]['date'], yearfirst=True, dayfirst= True, errors = 'coerce')
    casas[i]['weekDay'] = casas[i]['date'].dt.weekday
    casas[i]['hours'] = casas[i]['date'].dt.hour
    casas[i]['EnergyNextHour'] = casas[i]['activeEnergy'].shift(-1)
    casas[i]['EnergyNext2Hours'] = casas[i]['activeEnergy'].shift(-2)
    casas[i].drop(casas[i].index[-3:], inplace = True)
    #casas[i].dropna(axis = 0, how = 'any', inplace = True)
    
    #casas[i] = casas[i][casas[i]['activeEnergy'] < 4*casas[i]['activeEnergy'].std()]

# %%
a = 2

# %%
print(pd.isnull(casas[a]).any())
#df.loc[df['column_name'] == some_value]

casas[a].head()
# Out:
# date                False
# activeEnergy        False
# cepa                False
# cepb                False
# cepc                False
# weekDay             False
# hours               False
# EnergyNextHour      False
# EnergyNext2Hours    False
# dtype: bool
#                  date  activeEnergy  cepa  cepb  cepc  weekDay  hours  \
# 0 2017-03-01 00:00:00          1408   192   548   668        2      0
# 1 2017-03-01 01:00:00          1316   184   512   620        2      1
# 2 2017-03-01 02:00:00          1297   171   509   617        2      2
# 3 2017-03-01 03:00:00          1278   174   499   605        2      3
# 4 2017-03-01 04:00:00          1279   187   492   600        2      4
#
#    EnergyNextHour  EnergyNext2Hours
# 0          1316.0            1297.0
# 1          1297.0            1278.0
# 2          1278.0            1279.0
# 3          1279.0            1239.0
# 4          1239.0            1255.0

# %%
casas[a].plot(x = 'date', y = ['activeEnergy'])#, xlim = ['2017-03-01 00:00:00', ['2017-03-02 00:00:00']])
plt.show()
casas[a].plot(x = 'date', y = ['activeEnergy'], xlim = ['2017-06-07 00:00:00', ['2017-06-10 00:00:00']])
plt.show()

# %% [markdown]
# ## Truncar os dados

# %%
train_set = casas[a][casas[a]['date'] < '2017-08-15 00:00:00']
test_set = casas[a][casas[a]['date'] > '2017-08-15 00:00:00']#.reset_index()

# %% [markdown]
# ## Retirar tendência

# %%
from sklearn.linear_model import LinearRegression
linearReg = LinearRegression()
#print(train_set.index.shape, train_set['activeEnergy'].shape)
linearReg.fit(train_set.index[:, np.newaxis], train_set['activeEnergy'])
train_set_without_tendency = train_set['activeEnergy'] - linearReg.predict(train_set.index[:, np.newaxis])
plt.plot(train_set['activeEnergy'])
plt.plot(train_set_without_tendency)
plt.show()

# %%
F = train_set.set_index('date')
#print(F.index.freq)
s = sm.tsa.seasonal_decompose(F.activeEnergy)

# %%
fig, axes = plt.subplots(4,1, figsize = (12, 6))
axes[0].plot(train_set.set_index('date')['activeEnergy'])
axes[0].set_title('Série original')
axes[1].plot(s.trend)
axes[1].set_title('Série de tendência')
axes[2].plot(s.seasonal)
axes[2].set_title('Série de sazonalidade')
axes[3].plot(s.resid)
axes[3].set_title('Série residual')
plt.tight_layout()
plt.show()

# %%
s.seasonal.plot(xlim = ['2017-06-02', '2017-06-03'])
plt.title('Sazonalidade aditiva diária')
plt.show()

# %%
train_set_without_tendency = train_set.set_index('date')['activeEnergy'] - s.trend
train_set.set_index('date').plot(y = ['activeEnergy'])
train_set_without_tendency.plot()
plt.title('Série sem tendência')
plt.legend(['Original', 'Sem tendência'])
plt.show()

# %%
train_set_without_season = train_set_without_tendency - s.seasonal
train_set.set_index('date').plot(y = ['activeEnergy'])
train_set_without_season.plot()
plt.legend(['Original', 'Sem sazonalidade e tendência'])
plt.title('Série sem sazonalidade e tendência')
plt.show()

# %%
plt.psd(s.resid.dropna(), NFFT = 512, Fs = 1/60)
plt.title('Análise espectral da série residual')
plt.show()
plt.psd(F.activeEnergy.dropna(), NFFT = 512, Fs = 1/60)
plt.title('Análise espectral da série original')
plt.show()

# %%
train_set.set_index('date', inplace = True)
train_set['ResidualSeries'] = s.resid
train_set['SeasonalSeries'] = s.seasonal
train_set['TrendSeries'] = s.trend
train_set.dropna(axis = 0, how = 'any', inplace = True)
train_set.head()
# Out:
# C:\Users\Pedro\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Pedro\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Pedro\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\Pedro\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                      activeEnergy  cepa  cepb  cepc  weekDay  hours  \
# date
# 2017-03-01 12:00:00           513   273    33   207        2     12
# 2017-03-01 13:00:00           575   335    40   200        2     13
# 2017-03-01 14:00:00           483   307    38   138        2     14
# 2017-03-01 15:00:00           550   301     8   241        2     15
# 2017-03-01 16:00:00           446   294     5   147        2     16
#
#                      EnergyNextHour  EnergyNext2Hours  ResidualSeries  \
# date
# 2017-03-01 12:00:00           575.0             483.0     -144.006249
# 2017-03-01 13:00:00           483.0             550.0      -61.558834
# 2017-03-01 14:00:00           550.0             446.0     -139.123970
# 2017-03-01 15:00:00           446.0             418.0     -110.017670
# 2017-03-01 16:00:00           418.0             420.0     -239.082931
#
#                      SeasonalSeries  TrendSeries
# date
# 2017-03-01 12:00:00     -245.827084   902.833333
# 2017-03-01 13:00:00     -268.503666   905.062500
# 2017-03-01 14:00:00     -286.688530   908.812500
# 2017-03-01 15:00:00     -251.898997   911.916667
# 2017-03-01 16:00:00     -228.896236   913.979167

# %%
test_set.set_index('date', inplace = True)
test_set = test_set[:'2017-08-26']
print(test_set.index.freq)
test_set.tail()
# Out:
# None
#                      activeEnergy  cepa  cepb  cepc  weekDay  hours  \
# date
# 2017-08-26 06:00:00           537   159   158   220        5      6
# 2017-08-26 07:00:00           505   142   101   262        5      7
# 2017-08-26 08:00:00           591   298    40   253        5      8
# 2017-08-26 09:00:00           430   261    -1   170        5      9
# 2017-08-26 10:00:00           108    82     6    20        5     10
#
#                      EnergyNextHour  EnergyNext2Hours
# date
# 2017-08-26 06:00:00           505.0             591.0
# 2017-08-26 07:00:00           591.0             430.0
# 2017-08-26 08:00:00           430.0             108.0
# 2017-08-26 09:00:00           108.0               2.0
# 2017-08-26 10:00:00             2.0               0.0

# %%
#test_set.set_index('date', inplace = True)
F = test_set.activeEnergy
sTest = sm.tsa.seasonal_decompose(F, freq = 24)
test_set['ResidualSeries'] = sTest.resid
test_set['SeasonalSeries'] = sTest.seasonal
test_set['TrendSeries'] = sTest.trend
test_set.dropna(axis = 0, how = 'any', inplace = True)
test_set.head()
# Out:
#                      activeEnergy  cepa  cepb  cepc  weekDay  hours  \
# date
# 2017-08-15 13:00:00           228   146    24    58        1     13
# 2017-08-15 14:00:00           225   182    10    33        1     14
# 2017-08-15 15:00:00           435   348    37    50        1     15
# 2017-08-15 16:00:00           594   371    44   179        1     16
# 2017-08-15 17:00:00           259   207    10    42        1     17
#
#                      EnergyNextHour  EnergyNext2Hours  ResidualSeries  \
# date
# 2017-08-15 13:00:00           225.0             435.0       74.418868
# 2017-08-15 14:00:00           435.0             594.0       75.894247
# 2017-08-15 15:00:00           594.0             259.0      132.005990
# 2017-08-15 16:00:00           259.0             259.0      302.038187
# 2017-08-15 17:00:00           259.0             297.0      -42.637950
#
#                      SeasonalSeries  TrendSeries
# date
# 2017-08-15 13:00:00     -350.439702   504.020833
# 2017-08-15 14:00:00     -357.435914   506.541667
# 2017-08-15 15:00:00     -208.443490   511.437500
# 2017-08-15 16:00:00     -222.559020   514.520833
# 2017-08-15 17:00:00     -212.028717   513.666667

# %% [markdown]
# ## Pré processamento dos dados

# %%
matrix =  casas[a].as_matrix(columns = ['activeEnergy', 'cepa', 'cepb', 'cepc', 'weekDay', 
                                        'hours', 'EnergyNextHour', 'EnergyNext2Hours']).T
print(matrix.shape)
correlationCoef = np.corrcoef(matrix[:,3:])
# Out:
# (8, 4311)

# %%
sb.heatmap(np.abs(correlationCoef),
           annot=True, cmap = 'YlOrRd', vmin = 0, vmax =  1,
          xticklabels = ['activeEnergy', 'cepa', 'cepb', 'cepc', 'weekDay', 'hours', 'EnergyNextHour', 'EnergyNext2Hours'],
          yticklabels = ['activeEnergy', 'cepa', 'cepb', 'cepc', 'weekDay', 'hours', 'EnergyNextHour', 'EnergyNext2Hours'])
plt.title('Abs Correlation matrix')
plt.show()

# %% [markdown]
# ## Regressão com Multilayer Perceptron

# %%
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using Theano backend.

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back)]
        dataX.append(a)
        dataY.append(dataset[i + look_back])

    return np.array(dataX), np.array(dataY)

# %%
train_set.shape
#create_dataset(train_series, look_back = 6)
# Out:
# (3984, 11)

# %%
#len(train_set['ResidualSeries'].values)
train_values = train_set['ResidualSeries'].values
train_mean = train_set['ResidualSeries'].mean()
train_std = train_set['ResidualSeries'].std()
train_values -= train_mean
train_values /= train_std


test_values = test_set['ResidualSeries'].values
test_mean = test_set['ResidualSeries'].mean()
test_std = test_set['ResidualSeries'].std()
test_values -= test_mean
test_values /= test_std

x, y = create_dataset(train_values, look_back = 6)
testx, testy = create_dataset(test_values, look_back = 6)
print(y[:10], '\n',train_values[:10])
# Out:
# [-1.30082785 -0.78276327 -0.0438935   1.9399958   1.04458519  0.9207727
#   0.79001312  0.9148545   1.07973498  0.95330323]
#  [-0.69117614 -0.29497605 -0.66771441 -0.52784442 -1.14806603 -1.29195024
#  -1.30082785 -0.78276327 -0.0438935   1.9399958 ]

# %%
model = Sequential()
model.add(Dense(32, input_dim = 6, activation = 'tanh'))
model.add(Dense(1))
model.compile(loss = 'mean_squared_error', optimizer = 'adam')

# %%
history = model.fit(x, y, epochs = 200, validation_split = 0.2, batch_size = 41, verbose =  2)
# Out:
# Train on 3181 samples, validate on 796 samples
# Epoch 1/200
# 0s - loss: 0.6422 - val_loss: 0.4405
# Epoch 2/200
# 0s - loss: 0.5618 - val_loss: 0.4368
# Epoch 3/200
# 0s - loss: 0.5521 - val_loss: 0.4307
# Epoch 4/200
# 0s - loss: 0.5457 - val_loss: 0.4286
# Epoch 5/200
# 0s - loss: 0.5420 - val_loss: 0.4248
# Epoch 6/200
# 0s - loss: 0.5387 - val_loss: 0.4274
# Epoch 7/200
# 0s - loss: 0.5374 - val_loss: 0.4231
# Epoch 8/200
# 0s - loss: 0.5359 - val_loss: 0.4221
# Epoch 9/200
# 0s - loss: 0.5314 - val_loss: 0.4237
# Epoch 10/200
# 0s - loss: 0.5312 - val_loss: 0.4199
# Epoch 11/200
# 0s - loss: 0.5301 - val_loss: 0.4206
# Epoch 12/200
# 0s - loss: 0.5280 - val_loss: 0.4183
# Epoch 13/200
# 0s - loss: 0.5275 - val_loss: 0.4167
# Epoch 14/200
# 0s - loss: 0.5251 - val_loss: 0.4158
# Epoch 15/200
# 0s - loss: 0.5249 - val_loss: 0.4166
# Epoch 16/200
# 0s - loss: 0.5226 - val_loss: 0.4213
# Epoch 17/200
# 0s - loss: 0.5213 - val_loss: 0.4187
# Epoch 18/200
# 0s - loss: 0.5202 - val_loss: 0.4228
# Epoch 19/200
# 0s - loss: 0.5212 - val_loss: 0.4183
# Epoch 20/200
# 0s - loss: 0.5190 - val_loss: 0.4125
# Epoch 21/200
# 0s - loss: 0.5175 - val_loss: 0.4173
# Epoch 22/200
# 0s - loss: 0.5180 - val_loss: 0.4157
# Epoch 23/200
# 0s - loss: 0.5161 - val_loss: 0.4115
# Epoch 24/200
# 0s - loss: 0.5155 - val_loss: 0.4119
# Epoch 25/200
# 0s - loss: 0.5153 - val_loss: 0.4187
# Epoch 26/200
# 0s - loss: 0.5148 - val_loss: 0.4114
# Epoch 27/200
# 0s - loss: 0.5152 - val_loss: 0.4118
# Epoch 28/200
# 0s - loss: 0.5142 - val_loss: 0.4150
# Epoch 29/200
# 0s - loss: 0.5119 - val_loss: 0.4111
# Epoch 30/200
# 0s - loss: 0.5116 - val_loss: 0.4126
# Epoch 31/200
# 0s - loss: 0.5114 - val_loss: 0.4128
# Epoch 32/200
# 0s - loss: 0.5124 - val_loss: 0.4156
# Epoch 33/200
# 0s - loss: 0.5115 - val_loss: 0.4123
# Epoch 34/200
# 0s - loss: 0.5117 - val_loss: 0.4082
# Epoch 35/200
# 0s - loss: 0.5100 - val_loss: 0.4108
# Epoch 36/200
# 0s - loss: 0.5094 - val_loss: 0.4080
# Epoch 37/200
# 0s - loss: 0.5109 - val_loss: 0.4099
# Epoch 38/200
# 0s - loss: 0.5099 - val_loss: 0.4134
# Epoch 39/200
# 0s - loss: 0.5104 - val_loss: 0.4096
# Epoch 40/200
# 0s - loss: 0.5093 - val_loss: 0.4103
# Epoch 41/200
# 0s - loss: 0.5110 - val_loss: 0.4113
# Epoch 42/200
# 0s - loss: 0.5084 - val_loss: 0.4110
# Epoch 43/200
# 0s - loss: 0.5084 - val_loss: 0.4089
# Epoch 44/200
# 0s - loss: 0.5081 - val_loss: 0.4078
# Epoch 45/200
# 0s - loss: 0.5069 - val_loss: 0.4096
# Epoch 46/200
# 0s - loss: 0.5083 - val_loss: 0.4076
# Epoch 47/200
# 0s - loss: 0.5100 - val_loss: 0.4095
# Epoch 48/200
# 0s - loss: 0.5070 - val_loss: 0.4103
# Epoch 49/200
# 0s - loss: 0.5064 - val_loss: 0.4093
# Epoch 50/200
# 0s - loss: 0.5076 - val_loss: 0.4104
# Epoch 51/200
# 0s - loss: 0.5089 - val_loss: 0.4111
# Epoch 52/200
# 0s - loss: 0.5062 - val_loss: 0.4087
# Epoch 53/200
# 0s - loss: 0.5058 - val_loss: 0.4084
# Epoch 54/200
# 0s - loss: 0.5069 - val_loss: 0.4073
# Epoch 55/200
# 0s - loss: 0.5052 - val_loss: 0.4067
# Epoch 56/200
# 0s - loss: 0.5065 - val_loss: 0.4049
# Epoch 57/200
# 0s - loss: 0.5051 - val_loss: 0.4133
# Epoch 58/200
# 0s - loss: 0.5061 - val_loss: 0.4142
# Epoch 59/200
# 0s - loss: 0.5041 - val_loss: 0.4108
# Epoch 60/200
# 0s - loss: 0.5054 - val_loss: 0.4091
# Epoch 61/200
# 0s - loss: 0.5040 - val_loss: 0.4072
# Epoch 62/200
# 0s - loss: 0.5051 - val_loss: 0.4155
# Epoch 63/200
# 0s - loss: 0.5046 - val_loss: 0.4058
# Epoch 64/200
# 0s - loss: 0.5030 - val_loss: 0.4065
# Epoch 65/200
# 0s - loss: 0.5047 - val_loss: 0.4058
# Epoch 66/200
# 0s - loss: 0.5034 - val_loss: 0.4073
# Epoch 67/200
# 0s - loss: 0.5030 - val_loss: 0.4105
# Epoch 68/200
# 0s - loss: 0.5031 - val_loss: 0.4082
# Epoch 69/200
# 0s - loss: 0.5052 - val_loss: 0.4074
# Epoch 70/200
# 0s - loss: 0.5045 - val_loss: 0.4083
# Epoch 71/200
# 0s - loss: 0.5026 - val_loss: 0.4114
# Epoch 72/200
# 0s - loss: 0.5033 - val_loss: 0.4083
# Epoch 73/200
# 0s - loss: 0.5024 - val_loss: 0.4126
# Epoch 165/200
# 0s - loss: 0.4937 - val_loss: 0.4067
# Epoch 166/200
# 0s - loss: 0.4931 - val_loss: 0.4059
# Epoch 167/200
# 0s - loss: 0.4938 - val_loss: 0.4089
# Epoch 168/200
# 0s - loss: 0.4951 - val_loss: 0.4110
# Epoch 169/200
# 0s - loss: 0.4949 - val_loss: 0.4086
# Epoch 170/200
# 0s - loss: 0.4929 - val_loss: 0.4053
# Epoch 171/200
# 0s - loss: 0.4943 - val_loss: 0.4078
# Epoch 172/200
# 0s - loss: 0.4958 - val_loss: 0.4100
# Epoch 173/200
# 0s - loss: 0.4950 - val_loss: 0.4079
# Epoch 174/200
# 0s - loss: 0.4919 - val_loss: 0.4089
# Epoch 175/200
# 0s - loss: 0.4934 - val_loss: 0.4087
# Epoch 176/200
# 0s - loss: 0.4920 - val_loss: 0.4121
# Epoch 177/200
# 0s - loss: 0.4929 - val_loss: 0.4075
# Epoch 178/200
# 0s - loss: 0.4934 - val_loss: 0.4090
# Epoch 179/200
# 0s - loss: 0.4926 - val_loss: 0.4097
# Epoch 180/200
# 0s - loss: 0.4916 - val_loss: 0.4063
# Epoch 181/200
# 0s - loss: 0.4925 - val_loss: 0.4094
# Epoch 182/200
# 0s - loss: 0.4919 - val_loss: 0.4089
# Epoch 183/200
# 0s - loss: 0.4919 - val_loss: 0.4118
# Epoch 184/200
# 0s - loss: 0.4915 - val_loss: 0.4096
# Epoch 185/200
# 0s - loss: 0.4931 - val_loss: 0.4125
# Epoch 186/200
# 0s - loss: 0.4914 - val_loss: 0.4074
# Epoch 187/200
# 0s - loss: 0.4924 - val_loss: 0.4078
# Epoch 188/200
# 0s - loss: 0.4929 - val_loss: 0.4079
# Epoch 189/200
# 0s - loss: 0.4929 - val_loss: 0.4060
# Epoch 190/200
# 0s - loss: 0.4927 - val_loss: 0.4101
# Epoch 191/200
# 0s - loss: 0.4907 - val_loss: 0.4086
# Epoch 192/200
# 0s - loss: 0.4933 - val_loss: 0.4094
# Epoch 193/200
# 0s - loss: 0.4918 - val_loss: 0.4105
# Epoch 194/200
# 0s - loss: 0.4905 - val_loss: 0.4143
# Epoch 195/200
# 0s - loss: 0.4920 - val_loss: 0.4102
# Epoch 196/200
# 0s - loss: 0.4929 - val_loss: 0.4079
# Epoch 197/200
# 0s - loss: 0.4909 - val_loss: 0.4105
# Epoch 198/200
# 0s - loss: 0.4903 - val_loss: 0.4089
# Epoch 199/200
# 0s - loss: 0.4900 - val_loss: 0.4107
# Epoch 200/200
# 0s - loss: 0.4923 - val_loss: 0.4094

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()

# %%
predictedTest = model.predict(testx)
ploting = predictedTest*test_std + test_mean 
ploting += test_set['SeasonalSeries'].values[5:-2, np.newaxis] +test_set['TrendSeries'].values[5:-2, np.newaxis]
print(test_std, test_mean)
print(test_set['SeasonalSeries'].values.shape, test_set['TrendSeries'].values.shape)
print(predictedTest.shape, ploting.shape)
# Out:
# 178.1663610617089 3.8393229166667258
# (249,) (249,)
# (242, 1) (242, 1)

# %%
from sklearn.metrics import mean_absolute_error
print('Mean absolute error for residual series: %.4f'%mean_absolute_error(predictedTest, testy))
print('Mean absolute error for complete series: %.4f'%mean_absolute_error(ploting, test_set['activeEnergy'][5:-2].values))
# Out:
# Mean absolute error for residual series: 0.6695
# Mean absolute error for complete series: 53.8015

# %%
plt.figure(figsize = (12,6))
plt.title('Predicted residual series')
plt.plot(test_set['ResidualSeries'][5:-2].values, 'g')
plt.plot(predictedTest, 'r')
plt.legend(['Original', 'Predicted'])
plt.show()

plt.figure(figsize = (12,6))
plt.title('Predicted activeEnergy')
plt.plot(test_set['activeEnergy'][5:-2].values, 'g')
plt.plot(ploting, 'r')
plt.legend(['Original', 'Predicted'])
#plt.text('MSE %.3f'%)
plt.show()
